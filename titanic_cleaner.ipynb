# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My\ Drive/notebooks\
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive/My Drive/notebooks

# %%
# !ls
# Out:
#  1dconc.ipynb		'prediction-ann(.csv'
#  cnn-failedmodel.ipynb	'Random Forest vs Decision Trees.ipynb'
#  gender_submission.csv	 subcopy.csv
#  maam.ipynb		 submission.csv
#  NNsub.csv		 submitted.csv
#  prediction-ann1.csv	 SVCtitanic.ipynb
#  prediction-ann2.csv	 test.csv
#  prediction-ann3.csv	 titanic.ipynb
#  prediction-ann4.csv	 Titanic_Random_Forest.ipynb
#  prediction-ann5.csv	 titanic_x_test.csv
#  prediction-ann6.csv	 titanic_x_train.csv
#  prediction-ann7.csv	 titanic_x_y_train.csv
#  prediction-ann8.csv	 titanic_y_test.csv
#  prediction-ann9.csv	 titanic_y_train.csv
#  prediction-ann.csv	 train.csv

# %%
import pandas as pd
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")
print(train.shape,test.shape)
# Out:
# (891, 12) (418, 11)

# %%
test.columns
test['Survived']=-999
print(train.shape,test.shape)
# Out:
# (891, 12) (418, 12)

# %%
df=pd.concat([train,test]) 
df.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# (1309, 12)

# %%
#basic plan is to train the train model predict the survive add to the test,concat and then train the whole dataset

# %%
df.head(10)
# Out:
#     Age Cabin Embarked     Fare  ...     Sex  SibSp  Survived            Ticket
# 0  22.0   NaN        S   7.2500  ...    male      1         0         A/5 21171
# 1  38.0   C85        C  71.2833  ...  female      1         1          PC 17599
# 2  26.0   NaN        S   7.9250  ...  female      0         1  STON/O2. 3101282
# 3  35.0  C123        S  53.1000  ...  female      1         1            113803
# 4  35.0   NaN        S   8.0500  ...    male      0         0            373450
# 5   NaN   NaN        Q   8.4583  ...    male      0         0            330877
# 6  54.0   E46        S  51.8625  ...    male      0         0             17463
# 7   2.0   NaN        S  21.0750  ...    male      3         0            349909
# 8  27.0   NaN        S  11.1333  ...  female      0         1            347742
# 9  14.0   NaN        C  30.0708  ...  female      1         1            237736
#
# [10 rows x 12 columns]

# %%
#passenger Id

# %%
df['PassengerId'].isnull().sum() #passenger has no empty value , so it's a pass
# Out:
# 0

# %%
#survived

# %%
df['Survived'].isnull().sum() #none
# Out:
# 0

# %%
#pclass
df['Pclass'].isnull().sum()
# Out:
# 0

# %%
#name
df['Name'].isnull().sum()
# Out:
# 0

# %%
df['Name'].head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
import re
# Define function to extract titles from passenger names
def get_title(name):
    title_search = re.search(' ([A-Za-z]+)\.', name)
    # If the title exists, extract and return it.
    if title_search:
        return title_search.group(1)
    return ""

# %%
df['Title'] = df['Name'].apply(get_title)

# %%
df['Title'].isnull().sum()
# Out:
# 0

# %%
df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 
                                                 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Ms', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')

# %%
df['Title'].value_counts()
# Out:
# Mr        757
# Miss      264
# Mrs       198
# Master     61
# Rare       29
# Name: Title, dtype: int64

# %%
df.head(2)
# Out:
#     Age Cabin Embarked     Fare  ... SibSp  Survived     Ticket  Title
# 0  22.0   NaN        S   7.2500  ...     1         0  A/5 21171     Mr
# 1  38.0   C85        C  71.2833  ...     1         1   PC 17599    Mrs
#
# [2 rows x 13 columns]

# %%
#cabin
df['Cabin'].isnull().sum()
# Out:
# 1014

# %%
drop=['Cabin']
df.drop(drop,axis=1,inplace=True)

# %%
df.shape
# Out:
# (1309, 12)

# %%
#Embarked
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
df['Embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna('S', inplace = True)

# %%
df['Embarked'].value_counts()
# Out:
# S    916
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
#Fare
df['Fare'].fillna(df['Fare'].median(), inplace = True)

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %%
#filled the data except age, we would fill the age with linear regression/Random/SVM

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df['IsAlone'] = 1
df['IsAlone'].loc[df['FamilySize'] > 1] = 0
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
label=LabelEncoder()
df['Sex'] = label.fit_transform(df['Sex'])

# %%
df['Embarked'] = label.fit_transform(df['Embarked'])

# %%
drop2=["Ticket"]
df.drop(drop2,axis=1,inplace=True)
df
# Out:
#       Age  Embarked      Fare  ...   Title  FamilySize  IsAlone
# 0    22.0         2    7.2500  ...      Mr           2        0
# 1    38.0         0   71.2833  ...     Mrs           2        0
# 2    26.0         2    7.9250  ...    Miss           1        1
# 3    35.0         2   53.1000  ...     Mrs           2        0
# 4    35.0         2    8.0500  ...      Mr           1        1
# 5     NaN         1    8.4583  ...      Mr           1        1
# 6    54.0         2   51.8625  ...      Mr           1        1
# 7     2.0         2   21.0750  ...  Master           5        0
# 8    27.0         2   11.1333  ...     Mrs           3        0
# 9    14.0         0   30.0708  ...     Mrs           2        0
# 10    4.0         2   16.7000  ...    Miss           3        0
# 11   58.0         2   26.5500  ...    Miss           1        1
# 12   20.0         2    8.0500  ...      Mr           1        1
# 13   39.0         2   31.2750  ...      Mr           7        0
# ...

# %%
#0-master 1-miss 2- mr 3 - mrs 4-misc
df['Title'] = label.fit_transform(df['Title'])

# %%
drop2=["Name"]
df.drop(drop2,axis=1,inplace=True)
df
# Out:
#       Age  Embarked      Fare  Parch  ...  Survived  Title  FamilySize  IsAlone
# 0    22.0         2    7.2500      0  ...         0      2           2        0
# 1    38.0         0   71.2833      0  ...         1      3           2        0
# 2    26.0         2    7.9250      0  ...         1      1           1        1
# 3    35.0         2   53.1000      0  ...         1      3           2        0
# 4    35.0         2    8.0500      0  ...         0      2           1        1
# 5     NaN         1    8.4583      0  ...         0      2           1        1
# 6    54.0         2   51.8625      0  ...         0      2           1        1
# 7     2.0         2   21.0750      1  ...         0      0           5        0
# 8    27.0         2   11.1333      2  ...         1      3           3        0
# 9    14.0         0   30.0708      0  ...         1      3           2        0
# 10    4.0         2   16.7000      1  ...         1      1           3        0
# ...
